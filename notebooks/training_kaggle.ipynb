# %%
# Step 1 - Clone repository and install dependencies
# !git clone https://github.com/Vasco888888/mae-transformer-reconstruction.git project
# %cd project
# !pip install -r requirements.txt

# %%
# Step 2 - Launch TensorBoard for real-time monitoring
# %load_ext tensorboard
# %tensorboard --logdir experiments/logs

# %%
# Step 3 - Start the training process
# !python train.py

# %%
# Step 4 - Manually visualize reconstructions
# !python visualize.py

# %%
# Step 5 - Save model checkpoints to Kaggle output folder
# !cp *.pth /kaggle/working/
